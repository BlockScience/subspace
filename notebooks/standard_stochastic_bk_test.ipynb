# %% [markdown]
# # Subspace Digital Twin, Standard Stochastic Run
#
# *Danilo Lessa Bernardineli, November 2023*

# %% [markdown]
# ## Part 1. Dependences & Set-up

# %%
import sys
sys.path.append('../')

import os

import numpy as np
import pandas as pd


import matplotlib.pyplot as plt
import plotly.express as px
import plotly.io as pio
import plotly.graph_objects as go
import matplotlib.ticker as mtick
from matplotlib.ticker import FuncFormatter
import seaborn as sns
import random
pio.renderers.default = "png" # For GitHub rendering

# %% [markdown]
# ## Part 2. Simulation set-up & execution

# %%
# from subspace_model.experiment import standard_stochastic_run
# sim_df = standard_stochastic_run()

# Load simulation results from terminal ran experiment
sim_df = pd.read_pickle(
    "../data/simulations/standard_stochastic_run-2023-12-19_14-18-36.pkl.gz"
)

# %%
sim_df = sim_df.set_index(['label','run', 'days_passed'])

# %%
# print circulating supply for all day 1
sim_df.loc[(slice(None), slice(None), 1), "circulating_supply"]
# Out:
# label     run  days_passed
# standard  1    1              1.440015e+06
#           2    1              1.440015e+06
#           3    1              1.440015e+06
#           4    1              1.440015e+06
#           5    1              1.440015e+06
# Name: circulating_supply, dtype: float64

# %%
## Introduce randomness
sim_df["circulating_supply"] = sim_df["circulating_supply"].map(
    lambda x: x * random.uniform(0.95, 1.05)
)

# %%
## Introduce randomness
sim_df["issued_supply"] = sim_df["issued_supply"].map(
    lambda x: x * random.uniform(0.95, 1.05)
)

# %%
fig = go.Figure([
    go.Scatter(
        name='Circulating Supply',
        x=sim_df.index.get_level_values("days_passed"),
        y=round(sim_df["circulating_supply"].groupby(["label", "days_passed"]).mean(), 2),
        mode='lines',
        line=dict(color='rgb(31, 119, 180)'),
    ),
    go.Scatter(
        name='95% CI Upper',
        x=sim_df.index.get_level_values("days_passed"),
        y=round(sim_df["circulating_supply"].groupby(["label", "days_passed"]).max(), 2),
        mode='lines',
        marker=dict(color='#444'),
        line=dict(width=0),
        showlegend=False
    ),
    go.Scatter(
        name='95% CI Lower',
        x=sim_df.index.get_level_values("days_passed"),
        y=round(sim_df["circulating_supply"].groupby(["label", "days_passed"]).min(), 2),
        marker=dict(color='#444'),
        line=dict(width=0),
        mode='lines',
        fillcolor='rgba(68, 68, 68, 0.3)',
        fill='tonexty',
        showlegend=False
    )
])
fig.update_layout(
    xaxis_title='Days Passed',
    yaxis_title='Circulating Supply',
    title='Circular Supply Over Time',
    hovermode='x'
)
fig.update_yaxes(rangemode='tozero')
fig.show()

# %%
fig = go.Figure([
    go.Scatter(
        name='Issued Supply',
        x=sim_df.index.get_level_values("days_passed"),
        y=round(sim_df["issued_supply"].groupby(["label", "days_passed"]).mean(), 2),
        mode='lines',
        line=dict(color='rgb(31, 119, 180)'),
    ),
    go.Scatter(
        name='95% CI Upper',
        x=sim_df.index.get_level_values("days_passed"),
        y=round(sim_df["issued_supply"].groupby(["label", "days_passed"]).max(), 2),
        mode='lines',
        marker=dict(color='#444'),
        line=dict(width=0),
        showlegend=False
    ),
    go.Scatter(
        name='95% CI Lower',
        x=sim_df.index.get_level_values("days_passed"),
        y=round(sim_df["issued_supply"].groupby(["label", "days_passed"]).min(), 2),
        marker=dict(color='#444'),
        line=dict(width=0),
        mode='lines',
        fillcolor='rgba(68, 68, 68, 0.3)',
        fill='tonexty',
        showlegend=False
    )
])
fig.update_layout(
    xaxis_title='Days Passed',
    yaxis_title='Issued Supply',
    title='Issued Supply Over Time',
    hovermode='x'
)
fig.update_yaxes(rangemode='tozero')
fig.show()

# %%
fig = go.Figure([
    go.Scatter(
        name='Operator Pool Shares',
        x=sim_df.index.get_level_values("days_passed"),
        y=round(sim_df["operator_pool_shares"].groupby(["label", "days_passed"]).mean(), 2),
        mode='lines',
        line=dict(color='rgb(31, 119, 180)'),
    ),
    go.Scatter(
        name='95% CI Upper',
        x=sim_df.index.get_level_values("days_passed"),
        y=round(sim_df["operator_pool_shares"].groupby(["label", "days_passed"]).max(), 2),
        mode='lines',
        marker=dict(color='#444'),
        line=dict(width=0),
        showlegend=False
    ),
    go.Scatter(
        name='95% CI Lower',
        x=sim_df.index.get_level_values("days_passed"),
        y=round(sim_df["operator_pool_shares"].groupby(["label", "days_passed"]).min(), 2),
        marker=dict(color='#444'),
        line=dict(width=0),
        mode='lines',
        fillcolor='rgba(68, 68, 68, 0.3)',
        fill='tonexty',
        showlegend=False
    )
])
fig.update_layout(
    xaxis_title='Days Passed',
    yaxis_title='Operator Pool Shares',
    title='Operator Pool Shares Over Time',
    hovermode='x'
)
fig.update_yaxes(rangemode='tozero')
fig.show()

# %%
fig = go.Figure([
    go.Scatter(
        name='Nominator Pool Shares',
        x=sim_df.index.get_level_values("days_passed"),
        y=round(sim_df["nominator_pool_shares"].groupby(["label", "days_passed"]).mean(), 2),
        mode='lines',
        line=dict(color='rgb(31, 119, 180)'),
    ),
    go.Scatter(
        name='95% CI Upper',
        x=sim_df.index.get_level_values("days_passed"),
        y=round(sim_df["nominator_pool_shares"].groupby(["label", "days_passed"]).max(), 2),
        mode='lines',
        marker=dict(color='#444'),
        line=dict(width=0),
        showlegend=False
    ),
    go.Scatter(
        name='95% CI Lower',
        x=sim_df.index.get_level_values("days_passed"),
        y=round(sim_df["nominator_pool_shares"].groupby(["label", "days_passed"]).min(), 2),
        marker=dict(color='#444'),
        line=dict(width=0),
        mode='lines',
        fillcolor='rgba(68, 68, 68, 0.3)',
        fill='tonexty',
        showlegend=False
    )
])
fig.update_layout(
    xaxis_title='Days Passed',
    yaxis_title='Nominator Pool Shares',
    title='Nominator Pool Shares Over Time',
    hovermode='x'
)
fig.update_yaxes(rangemode='tozero')
fig.show()

# %%
# g_results = sns.lineplot(sim_df, x='days_passed', y='storage_fee_volume')
# g_results.set(yscale='log')

# sns.lineplot(sim_df, x='days_passed', y='storage_fee_volume')

fig = px.line(
    sim_df,
    x=sim_df.index.get_level_values("days_passed"),
    y="storage_fee_volume",
    title="AB Test Storage Fee Volume",
    color=sim_df.index.get_level_values("label"),
    labels={
        "storage_fee_volume": "Storage Fee Volume",
        "x": "Days Passed",
        "color": "Label",
    },
)
fig.update_layout(width=1200, height=500)
fig.show()

# %%
# g_results = sns.lineplot(sim_df, x='days_passed', y='compute_fee_volume')
# g_results.set(yscale='log')

# sns.lineplot(sim_df, x='days_passed', y='compute_fee_volume')

fig = px.line(
    sim_df,
    x=sim_df.index.get_level_values("days_passed"),
    y="compute_fee_volume",
    title="AB Test Compute Fee Volume",
    color=sim_df.index.get_level_values("label"),
    labels={
        "compute_fee_volume": "Compute Fee Volume",
        "x": "Days Passed",
        "color": "Label",
    },
)
fig.update_layout(width=1200, height=500)
fig.show()

# %%
# sns.lineplot(sim_df, x='days_passed', y='average_base_fee')

fig = px.line(
    sim_df,
    x=sim_df.index.get_level_values("days_passed"),
    y="average_base_fee",
    title="AB Test Average Base Fee",
    color=sim_df.index.get_level_values("label"),
    labels={
        "average_base_fee": "Average Base Fee",
        "x": "Days Passed",
        "color": "Label",
    },
)
fig.update_layout(width=1200, height=500)
fig.show()

# %%
# sns.lineplot(sim_df, x='days_passed', y='average_compute_weight_per_tx')

fig = px.line(
    sim_df,
    x=sim_df.index.get_level_values("days_passed"),
    y="average_compute_weight_per_tx",
    title="AB Test Average Compute Weight Per Tx",
    color=sim_df.index.get_level_values("label"),
    labels={
        "average_compute_weight_per_tx": "Average Compute Weight Per Tx",
        "x": "Days Passed",
        "color": "Label",
    },
)
fig.update_layout(width=1200, height=500)
fig.show()

# %%
# sns.lineplot(sim_df.history_size.diff().to_frame().query('days_passed > 0'), x='days_passed', y='history_size')

fig = px.line(
    sim_df.history_size.diff().to_frame().query('days_passed > 0'),
    x=sim_df.index.get_level_values("days_passed"),
    y="history_size",
    title="AB Test History Size",
    labels={
        "history_size": "History Size",
        "x": "Days Passed",
    },
)
fig.update_layout(width=1200, height=500)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 3
#       1 # sns.lineplot(sim_df.history_size.diff().to_frame().query('days_passed > 0'), x='days_passed', y='history_size')
# ----> 3 fig = px.line(
#       4     sim_df.history_size.diff().to_frame().query('days_passed > 0'),
#       5     x=sim_df.index.get_level_values("days_passed"),
#       6     y="history_size",
#       7     title="AB Test History Size",
#       8     labels={
#       9         "history_size": "History Size",
#      10         "x": "Days Passed",
#      11     },
#      12 )
#      13 fig.update_layout(width=1200, height=500)
#      14 fig.show()
#
# File ~/.virtualenvs/subspace/lib/python3.10/site-packages/plotly/express/_chart_types.py:264, in line(data_frame, x, y, line_group, color, line_dash, symbol, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, line_dash_sequence, line_dash_map, symbol_sequence, symbol_map, markers, log_x, log_y, range_x, range_y, line_shape, render_mode, title, template, width, height)
#     216 def line(
#     217     data_frame=None,
#     218     x=None,
#    (...)
#     258     height=None,
#     259 ) -> go.Figure:
#     260     """
#     261     In a 2D line plot, each row of `data_frame` is represented as vertex of
#     262     a polyline mark in 2D space.
#     263     """
# --> 264     return make_figure(args=locals(), constructor=go.Scatter)
#
# File ~/.virtualenvs/subspace/lib/python3.10/site-packages/plotly/express/_core.py:2076, in make_figure(args, constructor, trace_patch, layout_patch)
#    2073 layout_patch = layout_patch or {}
#    2074 apply_default_cascade(args)
# -> 2076 args = build_dataframe(args, constructor)
#    2077 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2078     args = process_dataframe_hierarchy(args)
#
# File ~/.virtualenvs/subspace/lib/python3.10/site-packages/plotly/express/_core.py:1485, in build_dataframe(args, constructor)
#    1482     args["color"] = None
#    1483 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1485 df_output, wide_id_vars = process_args_into_dataframe(
#    1486     args, wide_mode, var_name, value_name
#    1487 )
#    1489 # now that `df_output` exists and `args` contains only references, we complete
#    1490 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1491 # df_output
#    1493 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File ~/.virtualenvs/subspace/lib/python3.10/site-packages/plotly/express/_core.py:1212, in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1210         raise ValueError(err_msg)
#    1211 elif length and len(df_input[argument]) != length:
# -> 1212     raise ValueError(
#    1213         "All arguments should have the same length. "
#    1214         "The length of column argument `df[%s]` is %d, whereas the "
#    1215         "length of  previously-processed arguments %s is %d"
#    1216         % (
#    1217             field,
#    1218             len(df_input[argument]),
#    1219             str(list(df_output.keys())),
#    1220             length,
#    1221         )
#    1222     )
#    1223 else:
#    1224     col_name = str(argument)
#
# ValueError: All arguments should have the same length. The length of column argument `df[y]` is 3505, whereas the length of  previously-processed arguments ['x'] is 3510

# %%
sns.lineplot(sim_df.space_pledged.diff().to_frame().query('days_passed > 0'), x='days_passed', y='space_pledged')
# Out:
# <Axes: xlabel='days_passed', ylabel='space_pledged'>

# %%
sns.lineplot(sim_df, x='days_passed', y='block_utilization')
# Out:
# <Axes: xlabel='days_passed', ylabel='block_utilization'>

# %%
from subspace_model.trajectory_metrics import *


lst = []
for i, g_df in sim_df.groupby('run'):
    s = window_volatility(g_df.circulating_supply.diff()).reset_index()
    lst.append(s)

df = pd.concat(lst).dropna()
sns.lineplot(df, x='days_passed', y='circulating_supply')
# Out:
# 2023-12-19 21:16:15 - subspace-digital-twin - INFO
# ------------subspace-digital-twin------------
# <Axes: xlabel='days_passed', ylabel='circulating_supply'>
